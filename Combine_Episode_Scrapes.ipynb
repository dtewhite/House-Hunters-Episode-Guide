# %%
import pandas as pd

# %%
base_path = "Resources/House_Hunters_International_Episode_Scrape_"
csv_list = []
for i in range(1,67):
    csv_list.append(f'{base_path + str(i)}.csv')

# %%
df_list = []
for csv in csv_list:
    df_list.append(pd.read_csv(csv, index_col = 0))

# %%
combined_df = pd.concat(df_list)
combined_df
# Out:
#                    Number                                              Title  \
# 0     Season 1, Episode 1  Revisiting Big Renovations in the South of France
# 1     Season 1, Episode 2  Revisiting Remote Renovations in Australia, Ne...
# 2     Season 1, Episode 3  Revisiting Historic Renovations in Italy and F...
# 3     Season 1, Episode 4  Revisiting Euro Renovations in Berlin, Copenha...
# 4     Season 1, Episode 5  Revisiting Latin Renovations in Belize, Panama...
# ..                    ...                                                ...
# 7   Season 163, Episode 2         Quintessential vs. Convenient in Cambridge
# 8   Season 164, Episode 3   Beat Drops and Flip Flops in Koh Chang, Thailand
# 9   Season 165, Episode 5                  Trading Dreams in Dublin, Ireland
# 10  Season 166, Episode 1                            Staying Calm in Cologne
# 11  Season 167, Episode 1         Cupid's Arrow Strikes in Bangkok, Thailand
#
# ...

# %%
combined_df.to_csv('Resources/Combined_Episode_Scrapes.csv')
