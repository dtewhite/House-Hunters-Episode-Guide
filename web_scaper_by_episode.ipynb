# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint
# import ipython_bell

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/rustic-village-homes-in-portugal'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        not_done = False
        print("Scraping done!")
# Out:
# Scraping done!

# %%
browser.quit()

# %%
episode_dict = {}
episode_dict['Number'] = number_list
episode_dict['Title'] = title_list
episode_dict['Description'] = description_list
episode_dict['Link'] = url_list

# %%
episodes_df = pd.DataFrame(episode_dict)
episodes_df.tail(50)
# Out:
#                    Number                                              Title  \
# 0    Season 17, Episode 4                Couple Searches for Ecuador Getaway
# 1    Season 17, Episode 5  British Musician Wants Getaway in Bulgarian Co...
# 2    Season 17, Episode 6  A Canadian Couple Searches for a Vacation Home...
# 3    Season 17, Episode 7  Serial Renovators Look for an Affordable Home ...
# 4    Season 17, Episode 8  Steve Escapes by Buying a Vacation Home in Belize
# 5    Season 17, Episode 9     Brits Look for Home in France's Cognac Country
# 6   Season 17, Episode 10      American Surfers Search for Home in Nicaragua
# 7   Season 17, Episode 11          Dad Looks For Kid-Safe Home in Costa Rica
# 8   Season 17, Episode 12  An Oklahoma City Couple Looks for a Vacation H...
# 9   Season 17, Episode 13             Country Home Outside of Bologna, Italy
# 10   Season 18, Episode 1  Empty-Nesters Hope to Find a Vacation Home on ...
# 11   Season 18, Episode 2  Couple Searches for their Own Space in Nicarag...
# 12   Season 18, Episode 3    Family Searches for a Getaway in Turks & Caicos
# 13   Season 18, Episode 4  Looking for a Vacation Place in the Jungles of...
# 14   Season 18, Episode 5  Arkansas Couple Search for a Second Home on th...
# 15   Season 18, Episode 6  British Couple Search for a Vacation Home in M...
# 16   Season 18, Episode 7                Searching for a Condo in Cape Verde
# 17   Season 18, Episode 8     A Couple Searches for a Family Home in Ireland
# 18   Season 18, Episode 9  Chicago Realtors Search for a Vacation Home in...
# 19  Season 18, Episode 10   Looking for a Romantic Retreat in Abruzzo, Italy
# 20  Season 18, Episode 11     Brett and Eleni Want Dominican Republic Escape
# 21  Season 18, Episode 12   A British Couple Want 2nd Home in Southern Spain
