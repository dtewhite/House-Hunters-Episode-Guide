# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint
# import ipython_bell

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/couple-searches-for-ecuador-getaway'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        not_done = False
        print("Scraping done!")
# Out:
# Scraping done!

# %%
browser.quit()

# %%
episode_dict = {}
episode_dict['Number'] = number_list
episode_dict['Title'] = title_list
episode_dict['Description'] = description_list
episode_dict['Link'] = url_list

# %%
episodes_df = pd.DataFrame(episode_dict)
episodes_df.tail(50)
# Out:
#                    Number                                              Title  \
# 0    Season 15, Episode 7                              Michiganians In Paris
# 1    Season 15, Episode 8                   Updated Lofts in Historic Berlin
# 2    Season 15, Episode 9              Holiday Homes in Mediterranean Turkey
# 3   Season 15, Episode 10        Renovated Flats in Berlin's Trendy Boroughs
# 4   Season 15, Episode 11             Private Villas in a Turkish Beach Town
# 5   Season 15, Episode 12     A Young Family Heads Home to Carrasco, Uruguay
# 6   Season 15, Episode 13                  Hacienda Style in Historic Merida
# 7    Season 16, Episode 1                        Homes of Suburban Cape Town
# 8    Season 16, Episode 1                        Homes of Suburban Cape Town
# 9    Season 16, Episode 2                  Hunting with a Pro in Posh London
# 10   Season 16, Episode 3       The Fast Paced Apartment Market of Abu Dhabi
# 11   Season 16, Episode 4                  Apartment Hunting in Central Rome
# 12   Season 16, Episode 5  Greek Vacation Homes Along the Mediterranean C...
# 13   Season 16, Episode 6  Going Green in the Suburbs of Melbourne Australia
# 14   Season 16, Episode 7  Live Off the Grid on the Great Barrier Island ...
# 15   Season 16, Episode 8    California Based Family of Four Moves to Cairo.
# 16   Season 16, Episode 9  Country Home Versus City Home Along the Gold C...
# 17  Season 16, Episode 10   Hunting for Apartments in the Paris of the South
# 18  Season 16, Episode 11  Providence Couple Hunts for Their First Apartm...
# 19  Season 16, Episode 11  Providence Couple Hunts for Their First Apartm...
# 20  Season 16, Episode 12  Traditional English Cottages in Oxfordshire En...
# 21  Season 16, Episode 13        Country Homes Outside Prague Czech Republic
# 22   Season 17, Episode 1                 Adopted Homeland Hunt in Amsterdam
