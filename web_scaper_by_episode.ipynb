# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/a-country-villa-in-malta2'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        not_done = False
        print("Scraping done!")
# Out:
# Scraping done!

# %%
browser.quit()

# %%
episode_dict = {}
episode_dict['Number'] = number_list
episode_dict['Title'] = title_list
episode_dict['Description'] = description_list
episode_dict['Link'] = url_list

# %%
episodes_df = pd.DataFrame(episode_dict)
episodes_df.tail(50)
# Out:
#                    Number                                            Title  \
# 0    Season 11, Episode 1                         A Country Villa in Malta
# 1    Season 11, Episode 2                    Londoners Looking for Leisure
# 2    Season 11, Episode 3                            Vancouver Island Vibe
# 3    Season 11, Episode 4                               Paradise in Cyprus
# 4    Season 11, Episode 5                              Two Lives in Umbria
# 5    Season 11, Episode 6                                 BFFs in Brisbane
# 6    Season 11, Episode 7                                 Aiming for Aruba
# 7    Season 11, Episode 8                           French Country Fantasy
# 8    Season 12, Episode 1                   Relaxing Vacation Home in Fiji
# 9    Season 12, Episode 2             Relocating to the Dominican Republic
# 10   Season 12, Episode 3                      Finding a Home in Nicaragua
# 11   Season 12, Episode 4                    Vacation Condo Hunt in Belize
# 12   Season 12, Episode 5                   Second Home in Calabria, Italy
# 13   Season 12, Episode 6                    Vacation House Hunt in Roatan
# 14   Season 12, Episode 7  Vacation Home in Punta Cana, Dominican Republic
# 15   Season 12, Episode 8        Family-Friendly Vacation Cottage in Italy
# 16   Season 12, Episode 9                           Second Home in Morocco
# 17  Season 12, Episode 10                        Dream in Roatan, Honduras
# 18  Season 12, Episode 11  Canadians Buy in Punta Cana, Dominican Republic
# 19  Season 12, Episode 12                        Second Home in Costa Rica
# 20  Season 12, Episode 12                        Second Home in Costa Rica
# 21  Season 12, Episode 13                         A Second Home in Ecuador
# 22   Season 13, Episode 1                        Fresh Start in Costa Rica
# 23   Season 13, Episode 2                Luxury by the Beach in Costa Rica
# 24   Season 13, Episode 3                   Turks and Caicos Vacation Home
# 25   Season 13, Episode 4                   Vacation Retreat in Costa Rica
# 26   Season 13, Episode 5                          Luxury Buying in Panama
# 27   Season 13, Episode 6          Heading to St. Croix, US Virgin Islands
# 28   Season 13, Episode 7                            Second Home in Belize
#
#                                           Description  \
# 0   George Galea is no stranger to house-hunting. ...
# 1   Stephanie and Charlie May have lived in the fa...
# 2   Derrick and Shannon Nelson of Vancouver Island...
