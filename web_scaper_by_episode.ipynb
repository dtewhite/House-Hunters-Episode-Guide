# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/house-hunting-in-holland'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(1,5))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        not_done = False
        print("Scraping done!")
# Out:
# Scraping done!

# %%
browser.quit()

# %%
episode_dict = {}
episode_dict['Number'] = number_list
episode_dict['Title'] = title_list
episode_dict['Description'] = description_list
episode_dict['Link'] = url_list

# %%
episodes_df = pd.DataFrame(episode_dict)
episodes_df.tail(50)
# Out:
#                   Number                           Title  \
# 8    Season 3, Episode 1   Searching for Stockholm Space
# 9    Season 3, Episode 2            Escape to Costa Rica
# 10   Season 3, Episode 3       More Space in St. Maarten
# 11   Season 3, Episode 4   Turks and Caicos Condo Search
# 12   Season 3, Episode 5       Making the Move to Mexico
# 13   Season 3, Episode 6            Second Home in Italy
# 14   Season 3, Episode 7          Heading South to Italy
# 15   Season 3, Episode 8              Buenos Aires Bound
# 16   Season 3, Episode 9              New Aruban Address
# 17  Season 3, Episode 10              New to New Zealand
# 18  Season 3, Episode 11               Moving to Managua
# 19  Season 3, Episode 12       Looking to Own in Jamaica
# 20  Season 3, Episode 13           Flatmates in Scotland
# 21   Season 4, Episode 1                 Nesting in Cabo
# 22   Season 4, Episode 2          Settling Down in Paris
# 23   Season 4, Episode 3  Wanted: City of Lights Chateau
# 24   Season 4, Episode 4                   Casa in Spain
# 25   Season 4, Episode 5                  Cabo San Lucas
# 26   Season 4, Episode 6                    Paris Dreams
# 27   Season 4, Episode 7            Moving Up Down Under
# 28   Season 4, Episode 8                   Life in Ruins
# 29   Season 4, Episode 9  Goodbye Fresno, Hello Portugal
# 30  Season 4, Episode 10                 Dreams of Spain
# 31  Season 4, Episode 11              A Taste of Tuscany
# 32  Season 4, Episode 12                Turks and Caicos
# 33  Season 4, Episode 13                      Oh, Panama
# 34   Season 5, Episode 1             Bye-Bye Beach House
# 35   Season 5, Episode 2                 Away to Uruguay
# 36   Season 5, Episode 3                Spain is Calling
# 37   Season 5, Episode 4              Moving to Mazatlan
# 38   Season 5, Episode 5                Costa Rica Bound
# 39   Season 5, Episode 6                 Remain In Spain
# 40   Season 5, Episode 7               Leaving Las Vegas
