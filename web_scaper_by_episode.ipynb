# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/domestic-track-in-tasmania'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        browser.quit()
        print(f'There was an issue, restart the scraper from {current_url}')
        episode_dict = {}
        episode_dict['Number'] = number_list
        episode_dict['Title'] = title_list
        episode_dict['Description'] = description_list
        episode_dict['Link'] = url_list
        episodes_df = pd.DataFrame(episode_dict)
        not_done = False
# Out:
# There was an issue, restart the scraper from https://www.hgtv.com/shows/house-hunters-international/episodes/young-couple-butts-heads-in-bruges

# %%
episodes_df.tail(50)
# Out:
#                    Number                                              Title  \
# 0   Season 56, Episode 11                  Sea Views or Cityscapes in Sydney
# 1   Season 56, Episode 12                 Planning a Future in Paris, France
# 2   Season 56, Episode 13  Is Paradise Out of Reach in Mission Beach, Aus...
# 3    Season 57, Episode 1        Two Dudes and a Boat in Daintree, Australia
# 4    Season 57, Episode 2  Battling Over High Rises and Traditional Flats...
# 5    Season 57, Episode 3  American Dreams in the English Countryside in ...
# 6    Season 57, Episode 4  A Move to Los Cabos, Mexico Marks a Milestone ...
# 7    Season 57, Episode 5                                Much Love in Munich
# 8    Season 57, Episode 6           Business in Beautiful Busan, South Korea
# 9    Season 57, Episode 7              Surf, Sun and Jobs in Four Mile Beach
# 10   Season 57, Episode 8                      You've Got the Quito My Heart
# 11   Season 57, Episode 9                              Chicopee to Barcelona
# 12  Season 57, Episode 10            Torn Over Where to be in Split, Croatia
# 13  Season 57, Episode 11   Town Center or River Views in Carrick on Shannon
# 14  Season 57, Episode 12                Fight or Flight in Arcachon, France
# 15  Season 57, Episode 13                Asking for Authenticity in Thailand
# 16   Season 58, Episode 1               Back to Nature in Panguipulli, Chile
# 17   Season 58, Episode 2               Married and Motoring in Milan, Italy
# 18   Season 58, Episode 3  Reconnecting in Retirement in Dominical, Costa...
# 19   Season 58, Episode 4                           When Ajman loves a Woman
# 20   Season 58, Episode 5        Beautiful Backdrop in Tamarindo, Costa Rica
# 21   Season 58, Episode 6  A Family of Five Strives to Find a Full-Size H...
# 22   Season 58, Episode 7                  Quality Time in Bern, Switzerland
# 23   Season 58, Episode 8                       Risky Beach Business in Leon
# 24   Season 58, Episode 9                            Living Life in La Baule
# 25  Season 58, Episode 10      Managing Married Life in Melbourne, Australia
# 26  Season 58, Episode 11                 Searching for Keys in Cabo, Mexico
# 27  Season 58, Episode 12        Seeking Common Ground in Frankfurt, Germany
# 28  Season 58, Episode 13  Seeking a Gem on the Caribbean Island of St. M...
