# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/cashing-in-your-chips-on-the-remote-isle-of-man'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        browser.quit()
        print(f'There was an issue, restart the scraper from {current_url}')
        episode_dict = {}
        episode_dict['Number'] = number_list
        episode_dict['Title'] = title_list
        episode_dict['Description'] = description_list
        episode_dict['Link'] = url_list
        episodes_df = pd.DataFrame(episode_dict)
        not_done = False
# Out:
# There was an issue, restart the scraper from https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces.
# There was a problem here while scaping on page https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces
# There was an issue, restart the scraper from https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces.
# There was a problem here while scaping on page https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces
# There was an issue, restart the scraper from https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces.
# There was a problem here while scaping on page https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces
# There was an issue, restart the scraper from https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces.
# ...

# %%
episodes_df.tail(50)
# Out:
#                    Number                                              Title  \
# 44   Season 36, Episode 7  Seeking a Pied a Terre and Investment Property...
# 45   Season 36, Episode 8             Living Well in Wellington, New Zealand
# 46   Season 36, Episode 9                  Warming Up On the Island of Malta
# 47  Season 36, Episode 10        Friends Start a New Career in Izmir, Turkey
# 48  Season 36, Episode 11                      Young Tennis Pros On the Move
# 49  Season 36, Episode 12  Traveling Family Sets Permanent Roots Down in ...
# 50  Season 36, Episode 12  Traveling Family Sets Permanent Roots Down in ...
# 51  Season 36, Episode 13                         Making Headlines in Madrid
# 52   Season 37, Episode 1  Investing in a New Lifestyle in Port Douglas, ...
# 53   Season 37, Episode 2  Choosing Family and Community in Sesto Calende...
# 54   Season 37, Episode 3               Luxury Living on Grand Cayman Island
# ...

# %%
episodes_df.to_csv('Resources/House_Hunters_International_Episode_Scrape_16.csv')

# %%
episodes_df.iloc[-1,-1]
# Out:
# 'https://www.hgtv.com/shows/house-hunters-international/episodes/limas-many-faces'
