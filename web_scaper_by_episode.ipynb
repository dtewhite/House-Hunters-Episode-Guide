# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from function import combine_data
import pandas as pd
import time
import pprint
from random import randint
# import ipython_bell

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/88.0.4324.96/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Dan\.wdm\drivers\chromedriver\win32\88.0.4324.96]

# %%
url = 'https://www.hgtv.com/shows/house-hunters-international/episodes/michiganians-in-paris'
browser.visit(url)

# %%
not_done = True
number_list = [] 
url_list = []
title_list = []
description_list = []

# %%
while not_done:
    time.sleep(randint(1,5))
    try:
        html = browser.html
        soup = bs(html, 'html.parser')

        current_url = soup.find_all('link', rel='canonical')[0]['href']
        number = soup.find_all('div', class_='o-EpisodeLead__a-AssetInfo')[0].text.strip()
        title = soup.find_all('span', class_='o-EpisodeLead__a-HeadlineText')[0].text.strip()
        description = soup.find_all('div', class_='o-EpisodeLead__a-Description')[0].text.strip()

        number_list.append(number)
        url_list.append(current_url)
        title_list.append(title)
        description_list.append(description)

    except:
        print(f'There was a problem here while scaping on page {current_url}') 

    time.sleep(randint(5,10))
    try:
        browser.find_by_text('Next Episode').click()
    except:
        not_done = False
        print("Scraping done!")
# Out:
# Scraping done!

# %%
browser.quit()

# %%
episode_dict = {}
episode_dict['Number'] = number_list
episode_dict['Title'] = title_list
episode_dict['Description'] = description_list
episode_dict['Link'] = url_list

# %%
episodes_df = pd.DataFrame(episode_dict)
episodes_df.tail(50)
# Out:
#                    Number                                              Title  \
# 0    Season 13, Episode 8                       A Home on the Croatian Coast
# 1    Season 13, Episode 9                 A Villa in the Italian Countryside
# 2   Season 13, Episode 10                           Luxury Home in St. Lucia
# 3   Season 13, Episode 11                      Putting Down Roots in Croatia
# 4   Season 13, Episode 12                             First Home in Tel Aviv
# 5   Season 13, Episode 13                            Condo on Bulgaria Coast
# 6    Season 14, Episode 1                            Nicaragua Vacation Home
# 7    Season 14, Episode 2  New York Family Searches for a Second Home in ...
# 8    Season 14, Episode 3                         Second Home in Puerto Rico
# 9    Season 14, Episode 4                                 From Boat to Condo
# 10   Season 14, Episode 5             Choosing Homes on the Nicaraguan Coast
# 11   Season 14, Episode 6  A Canadian Couple Searches for a Vacation Home...
# 12   Season 14, Episode 7  Model Looks For Vacation Home in Vieques, Puer...
# 13   Season 14, Episode 8                     Beachfront Luxury Home in Fiji
# 14   Season 14, Episode 9       Brits Buy in Sicily for Their Growing Family
# 15  Season 14, Episode 10     Artist's Retreat in a Small Beach Town in Fiji
# 16  Season 14, Episode 10     Artist's Retreat in a Small Beach Town in Fiji
# 17  Season 14, Episode 11       Condo on the Caribbean Island of St. Maarten
# 18  Season 14, Episode 12  Busy Working Parents Search for Costa Rican Re...
# 19  Season 14, Episode 13  Irish Expat Wants To Buy a Home In Sofia, Bulg...
# 20   Season 15, Episode 1                                 Hip Edinburgh Flat
# 21   Season 15, Episode 2                             Virgin Island Paradise
# 22   Season 15, Episode 3                    A House For Five In Switzerland
# 23   Season 15, Episode 4                      *Hidden Harbor Vacation Homes
