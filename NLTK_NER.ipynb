# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
from nltk import Tree

# %%
df = pd.read_csv('Resources/House_Hunters_International_Final.csv', index_col=0)
df
# Out:
#                       Number  \
# 0        Specials, Episode 1
# 1        Specials, Episode 2
# 2        Specials, Episode 3
# 3        Specials, Episode 4
# 4        Specials, Episode 5
# ...                      ...
# 2108   Season 152, Episode 9
# 2109  Season 152, Episode 10
# 2110  Season 152, Episode 11
# 2111  Season 152, Episode 12
# 2112  Season 152, Episode 13
#
#                                                   Title  \
# 0     Revisiting Big Renovations in the South of France
# 1     Revisiting Remote Renovations in Australia, Ne...
# 2     Revisiting Historic Renovations in Italy and F...
# 3     Revisiting Euro Renovations in Berlin, Copenha...
# 4     Revisiting Latin Renovations in Belize, Panama...
# ...                                                 ...
# 2108                    Untapped Potential in Siem Reap
# 2109               Cooking Up a Fresh Start in Cambodia
# 2110                                The Da Nang Dilemma
# 2111                           Bargaining in Bratislava
# 2112                     Art Gallery in Puerto Vallarta
#
#                                             Description  \
# 0     House Hunters International is revisiting the ...
# 1     House Hunters International checks back in wit...
# 2     House Hunters International wondered what happ...
# 3     House Hunters International travels across Eur...
# 4     House Hunters International retraces the steps...
# ...                                                 ...
# 2108  A globetrotting Australian fell in love with C...
# 2109  A couple and their dog are relocating within C...
# 2110  Newlyweds leave their comfortable lives in Aus...
# 2111  A young professional longing for a European ex...
# 2112  A couple leaves their hectic work life in Chic...
#
#                                                    Link    Season  Episode
# 0     www.hgtv.com/shows/house-hunters-international...  Specials        1
# 1     www.hgtv.com/shows/house-hunters-international...  Specials        2
# 2     www.hgtv.com/shows/house-hunters-international...  Specials        3
# 3     www.hgtv.com/shows/house-hunters-international...  Specials        4
# 4     www.hgtv.com/shows/house-hunters-international...  Specials        5
# ...                                                 ...       ...      ...
# 2108  www.hgtv.com/shows/house-hunters-international...       152        9
# 2109  www.hgtv.com/shows/house-hunters-international...       152       10
# 2110  www.hgtv.com/shows/house-hunters-international...       152       11
# 2111  www.hgtv.com/shows/house-hunters-international...       152       12
# 2112  www.hgtv.com/shows/house-hunters-international...       152       13
#
# [2113 rows x 6 columns]

# %%
locations = []
for i in range(len(df['Title'])):
    sentence = df['Title'][i]
    
    ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))
    
    current_chunk = []
    continuous_chunk = []

    for subtree in ne_tree:
        if type(subtree) == Tree and subtree.label() == 'GPE':
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        if current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue
    
    locations.append(continuous_chunk)

# %%
i=0
for location in locations:
    if not location:
        i += 1

# %%
i
# Out:
# 379

# %%
locations
# Out:
# [['France'],
#  ['Australia', 'New Zealand'],
#  ['Italy', 'France'],
#  ['Berlin', 'Slovenia'],
#  ['Belize', 'Mexico'],
#  ['Italy'],
#  [],
#  ['Island'],
#  [],
#  ['Bali', 'Indonesia'],
#  [],
#  [],
#  ['Lights'],
#  ['Parisian'],
#  ['Belizean'],
#  ['Costa'],
#  [],
#  ['Paris'],
#  [],
#  [],
#  ['Seams', 'Buxton'],
#  [],
#  [],
#  [],
#  ['British', 'Thailand'],
#  ['St.'],
#  ['Fiji'],
#  [],
#  ['Belize'],
#  [],
#  ['Escape'],
#  ['St.'],
#  ['Turks'],
#  ['Mexico'],
#  ['Italy'],
#  ['South', 'Italy'],
#  [],
#  ['New'],
#  ['New', 'New Zealand'],
#  ['Managua'],
#  ['Own', 'Jamaica'],
#  ['Scotland'],
#  ['Cabo'],
#  ['Paris'],
#  [],
#  ['Casa', 'Spain'],
#  [],
#  ['Paris'],
#  [],
#  ['Life', 'Ruins'],
#  [],
#  ['Dreams', 'Spain'],
#  ['Tuscany'],
#  ['Turks'],
#  [],
#  [],
#  [],
#  ['Spain'],
#  ['Mazatlan'],
#  [],
#  ['Remain', 'Spain'],
#  [],
#  ['Hola', 'Mexico'],
#  [],
#  ['Casa', 'Belize'],
#  [],
#  [],
#  ['Casa'],
#  [],
#  ['City'],
#  ['Dive'],
#  [],
#  ['Home'],
#  [],
#  ['Tropical'],
#  [],
#  [],
#  ['Dominican Republic'],
#  ['Holland'],
#  ['Buenos'],
#  [],
#  ['Love', 'France'],
#  [],
#  [],
#  ['Room', 'Costa Rica'],
#  ['Find', 'Tokyo'],
#  ['Idyllic', 'Italy'],
#  ['Montreal'],
#  [],
#  ['Dominican'],
#  [],
#  [],
#  ['Spain'],
#  ['New Digs', 'Nicaragua'],
#  ['New Life', 'Lisbon'],
#  ['Malta'],
#  ['Italian'],
#  ['Canadian'],
#  ['Paradise', 'Belize'],
#  ['Bliss', 'France'],
#  ['Cyprus'],
#  ['Tokyo'],
#  ['Calgary'],
#  ['New', 'Prague'],
#  ['Adventure', 'Argentina'],
#  ['Edmonton'],
#  ['Spain'],
#  ['Germany'],
#  [],
#  ['France'],
#  [],
#  ['Ottawa'],
#  ['Malta'],
#  [],
#  [],
#  ['Paradise', 'Cyprus'],
#  ['Umbria'],
#  ['Brisbane'],
#  [],
#  ['French'],
#  ['Fiji'],
#  [],
#  ['Nicaragua'],
#  ['Belize'],
#  ['Calabria', 'Italy'],
#  ['Roatan'],
#  ['Punta Cana', 'Dominican Republic'],
#  ['Italy'],
#  ['Morocco'],
#  ['Dream', 'Roatan', 'Honduras'],
#  ['Punta Cana', 'Dominican Republic'],
#  ['Costa Rica'],
#  [],
#  ['Costa Rica'],
#  ['Luxury', 'Costa Rica'],
#  ['Turks'],
#  ['Costa Rica'],
#  ['Panama'],
#  ['St. Croix'],
#  ['Belize'],
#  ['Croatian'],
#  ['Italian'],
#  ['St.'],
#  ['Croatia'],
#  ['Tel Aviv'],
#  [],
#  [],
#  ['New York', 'Calabria', 'Italy'],
#  ['Puerto Rico'],
#  ['Boat'],
#  [],
#  ['Canadian'],
#  ['Vieques'],
#  ['Fiji'],
#  ['Sicily'],
#  ['Artist', 'Fiji'],
#  ['St.'],
#  [],
#  ['Irish', 'Sofia'],
#  [],
#  [],
#  ['Switzerland'],
#  [],
#  ['Slovenia'],
#  ['Best', 'Panama'],
#  ['Paris'],
#  ['Historic'],
#  ['Mediterranean Turkey'],
#  ['Berlin'],
#  ['Turkish'],
#  ['Carrasco'],
#  ['Historic'],
#  [],
#  ['Posh'],
#  [],
#  [],
#  ['Greek'],
#  ['Green'],
#  ['New Zealand'],
#  ['California', 'Cairo'],
#  ['Australia'],
#  ['South'],
#  ['Bangkok Thailand'],
#  ['Oxfordshire England'],
#  [],
#  ['Amsterdam'],
#  ['Abruzzo'],
#  ['Ireland', 'Calabria', 'Italy'],
#  [],
#  ['British', 'Bulgarian'],
#  ['Serial', 'France'],
#  ['Belize'],
#  ['France'],
#  ['American', 'Nicaragua'],
#  ['Dad', 'Costa Rica'],
#  ['Panama'],
#  ['Bologna', 'Italy'],
#  [],
#  ['Nicaragua'],
#  ['Turks'],
#  ['Belize'],
#  ['St.'],
#  ['British', 'Morocco'],
#  ['Cape'],
#  ['Ireland'],
#  ['Chicago', 'Salinas'],
#  ['Abruzzo', 'Italy'],
#  [],
#  ['British'],
#  [],
#  ['Vanuatu'],
#  ['Rustic', 'Portugal'],
#  ['Sydney'],
#  ['Melbourne'],
#  ['Modern', 'Bahrain'],
#  ['Nicaragua'],
#  ['Hanoi'],
#  ['Ho'],
#  ['Reykjavik Iceland'],
#  [],
#  ['Dubrovnik'],
#  [],
#  [],
#  ['Dream', 'Tel Aviv', 'Israel'],
#  ['Period', 'Buckinghamshire', 'England'],
#  ['Spacious', 'Amsterdam'],
#  ['Slovenia'],
#  ['Classic', 'Marrakesh'],
#  ['Bangalore', 'India'],
#  ['Brittany', 'France'],
#  ['South France'],
#  ['Modern', 'Odense'],
#  ['New', 'Okinawa', 'Japan'],
#  ['Downtown'],
#  ['Krakow', 'Poland'],
#  ['Spacious', 'Jerusalem'],
#  ['Spanish', 'Nicaragua'],
#  ['Bitburg', 'Germany'],
#  ['Santiago'],
#  ['Brussels', 'Belgium'],
#  ['Fredrikstad', 'Norway'],
#  ['Tokyo', 'Japan'],
#  ['Escape', 'Barcelona', 'Spain'],
#  ['Malmo'],
#  ['Stockholm', 'Sweden'],
#  ['Search', 'Adventure', 'Ulan Bator', 'Mongolia'],
#  ['Student', 'Poznan'],
#  ['Puglia', 'Italy'],
#  ['Izmit', 'Turkey'],
#  ['Montmartre', 'Paris'],
#  ['Amsterdam', 'Holland'],
#  ['Shanghai', 'China'],
#  ['Singapore'],
#  ['Buying', 'Veliko Tarnovo'],
#  ['Spain'],
#  ['Amman'],
#  ['Nuremberg', 'Germany'],
#  [],
#  ['Torino', 'Italy'],
#  ['Paradise', 'Port Douglas', 'Australia'],
#  ['Merida', 'Mexico'],
#  ['Portugal'],
#  ['Singapore'],
#  ['Chengdu', 'China'],
#  ['Hong Kong'],
#  ['Modern', 'Hong Kong'],
#  ['Village', 'Hertfordshire'],
#  ['Sicilian'],
#  ['Dubai'],
#  ['Uppsala', 'Sweden'],
#  [],
#  ['Tropical Australia'],
#  ['Newlyweds', 'Nairobi'],
#  ['Budapest', 'Hungary'],
#  ['Country', 'Wiltshire'],
#  ['Port Douglas', 'Australia'],
#  ['Tropical Salinas'],
#  ['Yerevan', 'Armenia'],
#  ['Downtown'],
#  ['Quality', 'Australia'],
#  ['Puerto Escondido', 'Mexico'],
#  ['Montevideo'],
#  ['Gaborone'],
#  ['Hossegor', 'France'],
#  ['Auckland', 'New Zealand'],
#  ['Normandy'],
#  ['Job', 'Kuala'],
#  ['France'],
#  ['Mode', 'Mediterranean'],
#  ['Surf', 'Manta'],
#  ['Hellerup'],
#  [],
#  ['Provence', 'France'],
#  ['Dutch', 'Delft', 'Netherlands'],
#  ['Cairns', 'Australia'],
#  ['Cairns', 'Australia'],
#  ['Sydney', 'Australia'],
#  ['Antwerp', 'Belgium'],
#  ['Salvador'],
#  [],
#  ['Beautiful'],
#  ['Single', 'Amsterdam'],
#  [],
#  [],
#  ['Villa'],
#  ['Rio'],
#  ['Medellin'],
#  ['Homeschool', 'La'],
#  ['Bermuda'],
#  ['Newlywed', 'Bangkok'],
#  ['Kent'],
#  ['Ansan'],
#  [],
#  ['Geneva'],
#  ['Most', 'Slovenia'],
#  ['Andalucia'],
#  ['Paris'],
#  ['Ostuni', 'Italy'],
#  ['Countdown', 'Gaeta', 'Italy'],
#  ['Jakarta'],
#  ['London'],
#  ['Germany'],
#  ['New Zealand'],
#  ['Istanbul'],
#  ['Love', 'Lima'],
#  ['Charente', 'France'],
#  ['Guatape', 'Colombia'],
#  ['Historic'],
#  ['Guatemala'],
#  ['Vodice', 'Croatia'],
#  ['Expat', 'Trinidad', 'Tobago'],
#  ['Berlin'],
#  ['Florence', 'Italy'],
#  ['Paris', 'France'],
#  ['Singapore'],
#  ['Salta', 'Argentina'],
#  ['Seller', 'Melbourne', 'Australia'],
#  ['Grenoble', 'France'],
#  ['Hunt', 'Historic'],
#  ['Drammen', 'Norway'],
#  ['Bishkek', 'Kyrgyzstan'],
#  ['San Jose'],
#  ['Bergen', 'Norway'],
#  ['Seoul'],
#  ['France'],
#  ['Siesta', 'Seville', 'Spain'],
#  ['Bali', 'Indonesia'],
#  ['Asuncion'],
#  ['Singapore'],
#  ['Tuscany', 'Italy'],
#  ['Tanzania'],
#  ['Famous', 'Bratislava'],
#  ['Windhoek'],
#  ['Ansbach', 'Germany'],
#  ['Roots', 'Reykjavik', 'Iceland'],
#  ['Marlborough', 'Massachusetts', 'Malaysia'],
#  [],
#  ['Madrid', 'Spain'],
#  ['Leisure', 'Trivigno', 'Italy'],
#  ['Portishead', 'England'],
#  ['Manila'],
#  ['Copenhagen'],
#  ['Together', 'Valencia', 'Spain'],
#  ['Florence', 'Italy'],
#  ['Remote'],
#  [],
#  ['New', 'Aalborg'],
#  ['New'],
#  ['Luxembourg'],
#  [],
#  ['Nantes', 'France'],
#  ['Lyon', 'France'],
#  ['Martinique'],
#  ['Portugal'],
#  [],
#  ['Gran Alacant', 'Spain'],
#  ['New', 'Brussels', 'Belgium'],
#  ['Tokyo', 'Japan'],
#  ['London'],
#  ['Anguilla'],
#  ['Naples'],
#  ['English'],
#  ['Canadian', 'Belize'],
#  ['Roatan'],
#  ['Paris', 'France'],
#  ['Taipei', 'Taiwan'],
#  ['Taiwan'],
#  ['France'],
#  ['Common', 'Cannes', 'France'],
#  ['San Juan'],
#  ['Nicaragua'],
#  ['New Start', 'Bogota', 'Colombia'],
#  ['Sydney', 'Australia'],
#  ['Italy'],
#  ['France'],
#  ['Norfolk Island Family', 'Brisbane', 'Australia'],
#  ['Melbourne', 'Australia'],
#  ['Wanderlust'],
#  ['Grand'],
#  ['Grenada'],
#  ['Pisa', 'Italy'],
#  ['Nassau'],
#  ['Hua Hin', 'Thailand'],
#  ['Australia'],
#  [],
#  ['Rota', 'Spain'],
#  ['Americans', 'Umbria'],
#  [],
#  ['San Salvador'],
#  [],
#  ['Puerto Vallarta', 'Mexico'],
#  ['Scotland'],
#  [],
#  ['Merida', 'Mexico'],
#  ['Willemstad'],
#  ['Florida'],
#  [],
#  ['Cairns', 'Australia'],
#  ['Misawa', 'Japan'],
#  ['Geneva'],
#  ['Belize'],
#  [],
#  ['Return'],
#  ['Love', 'Zagreb', 'Croatia'],
#  ['Paris'],
#  ['Wellington', 'New Zealand'],
#  ['Malta'],
#  ['New Career', 'Izmir', 'Turkey'],
#  [],
#  ['Denmark'],
#  ['Madrid'],
#  ['New', 'Port Douglas', 'Australia'],
#  ['Sesto Calende', 'Italy'],
#  ['Grand'],
#  ['Mérida', 'Mexico'],
#  ['Lucky', 'France'],
#  ['Gothenburg', 'Sweden'],
#  ['Buckinghamshire', 'England'],
#  ['Brisbane', 'Australia'],
#  ['Marbella'],
#  ['Australia'],
#  ['Manila'],
#  ['Battambang', 'Cambodia'],
#  [],
#  ['Rabat'],
#  ['Return', 'Sydney'],
#  [],
#  ['San Juan'],
#  [],
#  ['London', 'England'],
#  [],
#  ['London', 'England'],
#  ['Valencia'],
#  [],
#  ['Puerto Rico'],
#  ['Tokyo', 'Japan'],
#  [],
#  ['Madrid'],
#  ['Closer', 'Family', 'Sicily'],
#  [],
#  ['San Juan'],
#  ['Brisbane'],
#  ['Danes', 'Charlottenlund'],
#  ['Cabarete'],
#  [],
#  ['Helsinki', 'Finland'],
#  ['Berlin', 'Germany'],
#  ['Lima'],
#  ['Romantic', 'Argentina'],
#  [],
#  ['Scottish'],
#  ['London'],
#  ['Lima'],
#  [],
#  ['Barcelona', 'Spain'],
#  ['Lima'],
#  ['New Zealand'],
#  ['Penang', 'Malaysia'],
#  ['London', 'England'],
#  [],
#  ['Netherlands'],
#  [],
#  ['Witney England'],
#  ['Puerto Morelos', 'Mexico'],
#  ['Merida'],
#  ['European'],
#  ['Slopes', 'Solden'],
#  ['Bydgoszcz', 'Poland'],
#  ['Anew', 'Bogota'],
#  ['Space', 'Paris'],
#  ['Balance', 'Chiang Mai', 'Thailand'],
#  ['Florence', 'Italian'],
#  ['Norway'],
#  ['Verbier', 'Switzerland'],
#  [],
#  ['Dublin', 'Ireland'],
#  ['Kathmandu', 'Children'],
#  ['Puerto Morelos', 'Mexico'],
#  ['Lovestruck', 'Weymouth'],
#  ['Outdoor', 'Australia'],
#  [],
#  ['Australia'],
#  ['Montpellier', 'France'],
#  ['London', 'England'],
#  ['Concepcion'],
#  ['Sarajevo', 'Bosnia'],
#  ['Hungary'],
#  [],
#  ['Tarija', 'Bolivia'],
#  ['Europe'],
#  ['Hong Kong'],
#  ['Long', 'England'],
#  ['New York'],
#  ['Dutch', 'Gouda', 'Holland'],
#  ['New Trail', 'Krakow', 'Poland'],
#  [],
#  ['Middle', 'San Carlos', 'Mexico'],
#  ['Light'],
#  ['Scientific', 'Rome', 'Italy'],
#  ['Panama City'],
#  ['Quito'],
#  ['Breakfast', 'Bocas'],
#  [],
#  ['Romantic', 'Granada', 'Spain'],
#  ['Dimbulah', 'Australia'],
#  ['Hoi'],
#  ['Romantic', 'Puerto Morelos', 'Mexico'],
#  ['Cape Tribulation', 'Australia'],
#  ['Newlyweds', 'London', 'England'],
#  ['Puerto Cayo'],
#  ['Cairns', 'Australia'],
#  ['St.'],
#  [],
#  ['Bequia'],
#  ['Lyon', 'France'],
#  ['Brisbane'],
#  ['Italy', 'South', 'Ostuni'],
#  ['Huatulco', 'Mexico'],
#  ['Huatulco', 'Mexico'],
#  ['Idealism', 'Roatan', 'Honduras'],
#  ['Sweden'],
#  ['Brisbane'],
#  ['Cannes', 'France'],
#  ['London', 'England'],
#  ['San', 'Mexico'],
#  ['New', 'Australian'],
#  ['Cologne', 'Germany', 'Rhineland'],
#  ['Sweden'],
#  ['Texas'],
#  ['Dublin'],
#  ['New', 'Townsville'],
#  ['Tarifa', 'Spain'],
#  ['Succeed', 'Stockholm', 'Sweden'],
#  ['Munich', 'Germany'],
#  [],
#  ['Lifelong', 'Tamarindo'],
#  ['Tamarindo'],
#  ['Australia'],
#  ['Scotland'],
#  ['Puerto Cayo'],
#  ['London'],
#  ['Italy'],
#  [],
#  ['Canadian', 'Cabarete', 'Dominican Republic'],
#  [],
#  ['Seoul'],
#  ['Beverley'],
#  [],
#  ['Lisbon', 'Portugal'],
#  ['Kaiserslautern', 'Germany'],
#  ['Rome'],
#  ['Playa'],
#  ['Portuguese'],
#  ['Thai', 'Bangkok', 'Thailand'],
#  ['Mossman', 'Australia'],
#  ['Finland'],
#  ['Student', 'Glasgow', 'Scotland'],
#  ['U.S.'],
#  ['Copenhagen'],
#  ['Germany'],
#  ['Paris'],
#  ['New', 'Strasbourg', 'France'],
#  ['Dublin', 'Ireland'],
#  [],
#  ['Dubai'],
#  [],
#  [],
#  ['Cairns', 'Australia'],
#  ['St. Kitts', 'West'],
#  ['St.'],
#  ['Anew', 'Nassau'],
#  ['Spain'],
#  ['Brussels', 'Belgium'],
#  ['Collide', 'Copenhagen'],
#  ['Iceland'],
#  ['Test', 'Love', 'Tel Aviv', 'Israel'],
#  ['Los Angeles'],
#  ['Long'],
#  [],
#  ['Parisian'],
#  [],
#  ['London'],
#  ['Reykjavik', 'Iceland'],
#  ['Perth', 'Australia'],
#  ['San Juan'],
#  [],
#  ['Antigua'],
#  ['St. John'],
#  ['St. John', 'U.S.'],
#  ['Thai'],
#  ['Stuttgart', 'Germany'],
#  ['Flash'],
#  ['Wellington'],
#  [],
#  ['Belize City'],
#  [],
#  ['Lisbon'],
#  ['Band'],
#  ['Cannoli', 'Sicily', 'Italy'],
#  ['Amsterdam', 'Netherlands'],
#  ['Massachusetts', 'Sydney', 'Australia'],
#  ['France'],
#  ['Port Douglas', 'Australia'],
#  ['Puerto'],
#  [],
#  ['Australia'],
#  ['Sweet'],
#  ['Creature', 'Blackburn', 'England'],
#  ['Townsville', 'Australia'],
#  ['New', 'Aurland', 'Norway'],
#  ['Johannesburg', 'South Africa'],
#  ['Island', 'St.'],
#  ['Star', 'Rocky Point', 'Australia'],
#  ['San Juan'],
#  ['North Carolina', 'Belize'],
#  ['Auckland', 'New Zealand'],
#  ['Kawana', 'Australia'],
#  [],
#  ['Andalucia', 'Spain'],
#  [],
#  ['Prague'],
#  ['Rainbow Beach', 'Australia'],
#  ['Melbourne'],
#  ['Paris', 'France'],
#  ['New', 'New Family', 'Amsterdam'],
#  ['Tilburg', 'Netherlands'],
#  ['Eleuthera'],
#  ['Barranquilla', 'Colombia'],
#  ['Caloundra'],
#  ['Denmark'],
#  ['New Life'],
#  ['Rotterdam', 'Netherlands'],
#  ['Nice', 'France'],
#  ['Lithuania'],
#  ['Panama'],
#  ['Hello'],
#  ['New', 'Majorca', 'Spain'],
#  ['Country', 'Cape Town', 'South Africa'],
#  ['Playa Conchal'],
#  ['Marbella'],
#  ['Belgian', 'Brussels'],
#  ['Brit'],
#  [],
#  ['Orvieto', 'Italy'],
#  [],
#  ['Sand', 'Brisbane'],
#  ['Auckland', 'New Zealand'],
#  [],
#  ['Loughborough', 'England'],
#  ['House', 'Istanbul'],
#  [],
#  ['Kingston'],
#  ['Granada'],
#  ['Granada'],
#  ['London', 'England'],
#  ['Sydney'],
#  ['Paris', 'France'],
#  ['Reach', 'Australia'],
#  ['Daintree', 'Australia'],
#  ['Glasgow', 'Scotland'],
#  ['American', 'Bracknell', 'England'],
#  ['Los Cabos', 'Mexico'],
#  ['Munich'],
#  ['Business', 'Beautiful Busan', 'South Korea'],
#  ['Surf'],
#  [],
#  ['Chicopee'],
#  ['Split', 'Croatia'],
#  ['Carrick', 'Shannon'],
#  ['Flight', 'Arcachon', 'France'],
#  ['Thailand'],
#  ['Nature', 'Panguipulli'],
#  ['Milan', 'Italy'],
#  ['Retirement', 'Dominical'],
#  [],
#  ['Tamarindo'],
#  ['Five', 'Cambridge', 'England'],
#  ['Bern', 'Switzerland'],
#  ['Leon'],
#  ['La'],
#  ['Melbourne', 'Australia'],
#  ['Cabo', 'Mexico'],
#  ['Frankfurt', 'Germany'],
#  ['St.'],
#  [],
#  ['Business', 'Budget', 'Budapest', 'Hungary'],
#  ['New Digs', 'Dortmund', 'Germany'],
#  ['Island'],
#  ['Puerto Cayo'],
#  ['London'],
#  ['Amsterdam'],
#  ['Size', 'Dublin'],
#  ['Oliva', 'Spain'],
#  ['Florida', 'Belize'],
#  ['Spain'],
#  ['Obertrum'],
#  ['Belfast'],
#  ['Long', 'Provence', 'France'],
#  ['Osaka', 'Japan'],
#  ['Lulea', 'Sweden'],
#  ['Cyprus'],
#  ['New', 'England'],
#  ['English', 'Finance', 'Thailand'],
#  ['California', 'Chioggia', 'Italy'],
#  ['Bruges'],
#  ['Tasmania'],
#  ['Unknown', 'Ukraine'],
#  [],
#  ['Kathmandu'],
#  ['Papua'],
#  ['Ometepe'],
#  ['Malaysia'],
#  ['Gaborone'],
#  ['Space', 'Brussels', 'Belgium'],
#  ['Paris', 'France'],
#  ['Potsdam', 'Germany'],
#  [],
#  [],
#  [],
#  ['Demands', 'Leiden', 'Netherlands'],
#  ['Puerto Escondido', 'Mexico'],
#  ['San Sebastian', 'Spain'],
#  ['Romantic'],
#  ['Vevey', 'Switzerland'],
#  ['St.'],
#  ['San'],
#  ['Croatian', 'Korcula'],
#  [],
#  ['Parisian'],
#  ['Tango', 'Argentina'],
#  ['Colombian'],
#  [],
#  ['Hong Kong', 'China'],
#  ['Location', 'Bangkok', 'Thailand'],
#  ['Australia', 'New', 'Ghana'],
#  [],
#  ['Ho'],
#  ['Pet', 'Belize'],
#  ['Bad'],
#  [],
#  ['Lucca', 'Italy'],
#  ['Aruba'],
#  ['Surprise', 'Mexico'],
#  [],
#  [],
#  ['Shannon', 'Trieste', 'Italy'],
#  [],
#  ['England'],
#  ['Stockholm'],
#  ['Microfinance', 'Mongolia'],
#  ['Puerto Escondido', 'Mexico'],
#  ['Accustomed'],
#  [],
#  ['Northeast'],
#  ['Asian', 'Chengdu', 'China'],
#  ['Beijing'],
#  [],
#  ['France'],
#  ['Koh Samui', 'Thailand'],
#  [],
#  ['Love', 'Belize'],
#  ['Jakarta', 'Indonesia'],
#  ['Detour', 'Life', 'Greenland'],
#  ['Rotterdam'],
#  ['Mexico'],
#  [],
#  [],
#  ['Wacko'],
#  ['Bogota'],
#  [],
#  ['Californians', 'Costa Rica'],
#  [],
#  ['Amsterdam'],
#  ['Competa', 'Spain'],
#  ['Indecision', 'Brussels', 'Belgium'],
#  [],
#  ['Cape'],
#  ['Nothing'],
#  ['Berlin'],
#  ['Florida'],
#  ['South', 'Pricey Perth', 'Australia'],
#  [],
#  ['Rosarito Beach', 'Mexico'],
#  ['Roots', 'Rosarito'],
#  ['DIYreland'],
#  ['County Kildare', 'Ireland'],
#  ['La Serena'],
#  ['Spain'],
#  ['Paris'],
#  ['Paris'],
#  [],
#  [],
#  ['Piedmont', 'Italy'],
#  ['Barcelona'],
#  ['Warsaw', 'Poland'],
#  ['Asunción'],
#  ['Bucharest', 'Romania'],
#  ['Punta'],
#  [],
#  ['Australia'],
#  [],
#  ['Amsterdam'],
#  ['Ansbach'],
#  ['Esmeraldas'],
#  ['Brno'],
#  ['Brisbane', 'Australia'],
#  ['Beachfront', 'Punta Cana', 'Dominican Republic'],
#  ['Stockholm'],
#  ['Californians'],
#  ['San'],
#  [],
#  ['New Take', 'Talca'],
#  ['New Jobs', 'Roommates', 'Madrid', 'Spain'],
#  ['Australia'],
#  ['Auckland'],
#  ['Romania'],
#  ['Sao Paulo'],
#  ['Nest', 'Puerto'],
#  [],
#  ['Californians'],
#  ['Bali'],
#  [],
#  ['Rotterdam', 'Netherlands'],
#  [],
#  [],
#  [],
#  ['Taxis'],
#  ['Campania'],
#  ['South Africa'],
#  [],
#  ['Bermuda'],
#  ['Puppy', 'Perth'],
#  [],
#  ['Guanacaste'],
#  ['Le Perche', 'France'],
#  ['Tenerife'],
#  [],
#  ['Bearish', 'Bullish', 'Medellin', 'Colombia'],
#  [],
#  ['Bangor'],
#  [],
#  [],
#  ['Croatia'],
#  ['Panamanian'],
#  ['Paris', 'Newest'],
#  ['Roatan'],
#  ['Split', 'Urban', 'Lusaka', 'Zambia'],
#  ['Swaziland'],
#  ['Paris', 'France'],
#  ['Sense', 'Santiago'],
#  ['Guam'],
#  ['First', 'Guam'],
#  ['Zurich', 'Switzerland'],
#  ['New Life', 'South Africa'],
#  ['St.'],
#  ['St. Thomas'],
#  ['London'],
#  ['Anglesey'],
#  [],
#  ['Sydney', 'Australia'],
#  ['Battle', 'Puerto Penasco', 'Mexico'],
#  ['Manhattan', 'Scotland'],
#  ['Manuel Antonio'],
#  ['Brussels'],
#  ['Dusseldorf', 'Germany'],
#  ['Australian'],
#  ['Aberdeen', 'Scotland'],
#  ['Puerto Plata', 'Dominican Republic'],
#  ['Dare', 'Repair', 'Terrasson', 'France'],
#  ['Freeport'],
#  ['Tortola'],
#  ['Circles', 'London'],
#  ['Space', 'Brussels', 'Belgium'],
#  ['Kuwait', 'Kuantan', 'Malaysia'],
#  ['London'],
#  ['Rota', 'Spain'],
#  [],
#  ['Race'],
#  ['Singapore'],
#  ['Cambodia'],
#  ['Mulheim', 'Germany'],
#  [],
#  ['Grenada'],
#  ['Grenada'],
#  ['San Juan'],
#  [],
#  [],
#  ['Catalonia'],
#  ['Turin'],
#  ['Puerto'],
#  [],
#  ['San', 'Allende'],
#  ['Berlin'],
#  [],
#  [],
#  ['Countryside'],
#  [],
#  ['St.'],
#  ['Kiss'],
#  ['Africa'],
#  ['Home'],
#  [],
#  ['Hong Kong'],
#  ['Denver'],
#  ['City', 'Athens'],
#  ['Sint'],
#  [],
#  ['Love', 'New Delhi'],
#  ['Gurgaon', 'India'],
#  ['Love', 'Goa'],
#  ['Chiang'],
#  [],
#  [],
#  ['New Baby', 'Aberdeen', 'Scotland'],
#  ['Greater'],
#  ['Turnkey', 'Helsinki', 'Finland'],
#  ['Stockholm', 'Sweden'],
#  ['Italian', 'Iesi'],
#  ['Garabito'],
#  ['Nothing'],
#  ['France'],
#  ['Mom', 'New Life'],
#  ['Arusha', 'Tanzania'],
#  [],
#  [],
#  ['Granada', 'Spain'],
#  ['Warwick'],
#  [],
#  ['Guatemala'],
#  ['Space', 'Stockholm', 'Sweden'],
#  ['London'],
#  ['Denmark'],
#  [],
#  ['Nest', 'Rural Malaysia'],
#  [],
#  ['Napier'],
#  ['Christchurch', 'New Zealand'],
#  ['Puerto'],
#  [],
#  ['Liverpool'],
#  ['Netherlands', 'Amsterdam'],
#  ['Taipei'],
#  ['Texan', 'Oslo'],
#  ['Paris'],
#  ['Riga'],
#  [],
#  ['New Career', 'Malta'],
#  ['Island'],
#  ['Albania'],
#  [],
#  [],
#  ['Reality'],
#  ['Morelia', 'Mexico'],
#  ['Cardiff'],
#  ['Christchurch'],
#  ['Utila', 'Honduras'],
#  ['Solleftea'],
#  ['Julie'],
#  ['Grenada'],
#  ['Lake Atitlan'],
#  ['Isabela'],
#  [],
#  ['New Career', 'Malmo', 'Sweden'],
#  [],
#  [],
#  [],
#  ['Ulaanbaatar', 'Mongolia'],
#  ['Geilenkirchen', 'Germany'],
#  [],
#  ['Bad'],
#  ['Student', 'Malang', 'Indonesia'],
#  ['Flemish'],
#  ['Frankfurt', 'Germany'],
#  ['New'],
#  ['Panama'],
#  ['Irish', 'Dublin'],
#  [],
#  ['Canadian', 'Fiance', 'Italy'],
#  ['Azore'],
#  ['Chiang Mai', 'Thailand'],
#  ...]
